# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.linspace(-10, 10, 100)
y = np.log10(x)

fig, ax = plt.subplots()
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

plt.plot(x, y)
# Out:
# /tmp/ipykernel_5455/3516698901.py:6: RuntimeWarning: invalid value encountered in log10
#   y = np.log10(x)
