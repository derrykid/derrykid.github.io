# %%
import pandas as pd

df = pd.read_csv('data/telco_churn.csv')

# %% [markdown]
# # Grouping

# %% [markdown]
# Maps allow us to perform computation one value at a time. However, often we want to group our data and do specific transformation to the group.
#
# A `groupby()` makes the column to be the index of the Series, or dataframe

# %%
df.head(1)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                     1.0  False

# %%
df.groupby('State')['International plan'].count().head()
# Out:
# State
# AK    52
# AL    80
# AR    55
# AZ    64
# CA    34
# Name: International plan, dtype: int64

# %% [markdown]
# We want to count how often a customer calls. We can do so by `value_counts()` that we learn before.

# %%
# Series
df['Customer service calls'].value_counts()
# Out:
# 1.0    1179
# 2.0     758
# 0.0     696
# 3.0     428
# 4.0     166
# 5.0      66
# 6.0      22
# 7.0       9
# 9.0       2
# 8.0       2
# Name: Customer service calls, dtype: int64

# %% [markdown]
# We can reproduce the same output by grouping by

# %%
# groupby method will group that into dataframe
# so when we want to access the data we want, we pass the column we want
# hence here: df.groupby('col')['col']
df.groupby('Customer service calls')['Customer service calls'].count()
# Out:
# Customer service calls
# 0.0     696
# 1.0    1179
# 2.0     758
# 3.0     428
# 4.0     166
# 5.0      66
# 6.0      22
# 7.0       9
# 8.0       2
# 9.0       2
# Name: Customer service calls, dtype: int64

# %% [markdown]
# Note that these 2 produce same result, even though their labels are in different ordering.

# %% [markdown]
# ## Groupby and summary function
#
# Since it returns a series, we can use additional summary function to it

# %%
df['Customer service calls'].value_counts().max()
# Out:
# 1179

# %% [markdown]
# ## Groupby and apply function
#
# A groupby function can be viewed as that you generate a slice of DataFrame. Hence, we can use `apply()` to get the data we want.

# %% [markdown]
# Here we create a animal speed dataframe. We groupby animal, then scale the speed by dividing 100.

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon','Parrot', 'Parrot', 'Cat', 'Bird', 'Parrot'],
                    'Max Speed': [380., 370., 24., 26., 40., 33., 24.]})

df.groupby('Animal').apply(lambda df: df['Max Speed'] / 100)
# Out:
# Animal
# Bird    5    0.33
# Cat     4    0.40
# Falcon  0    3.80
#         1    3.70
# Parrot  2    0.24
#         3    0.26
#         6    0.24
# Name: Max Speed, dtype: float64

# %% [markdown]
# ## Groupby multiple columns

# %%
df = pd.read_csv('data/telco_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
# 2             41.38              121.2            110.0             10.30
# 3             50.90               61.9             88.0              5.26
# 4             28.34              148.3            122.0             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False
# 2                     0.0  False
# 3                     2.0  False
# 4                     3.0  False

# %%
df.groupby(['State', 'International plan'])

# %% [markdown]
# # Sorting
#
# The dataframe is sorted by index by default. You can sort by columns

# %%
df.sort_values(by='Total day charge').head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                      0                0.0              0.0
# 1397                      0                0.0              0.0
# 2736                     27                2.6            113.0
# 2753                      0                7.8             86.0
# 1986                      0                7.9            100.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1345              0.00              159.6            130.0             13.57
# 1397              0.00              192.1            119.0             16.33
# 2736              0.44              254.0            102.0             21.59
# 2753              1.33              171.4            100.0             14.57
# 1986              1.34              136.4             83.0             11.59
#
#       Total night minutes  Total night calls  Total night charge  \
# 1345                167.1               88.0                7.52
# 1397                168.8               95.0                7.60
# 2736                242.7              156.0               10.92
# 2753                186.5               80.0                8.39
# 1986                156.6               89.0                7.05
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1345                 6.8                 1               1.84
# 1397                 7.2                 4               1.94
# 2736                 9.2                 5               2.48
# 2753                12.9                 2               3.48
# 1986                12.1                 1               3.27
#
#       Customer service calls  Churn
# 1345                     4.0   True
# 1397                     1.0  False
# 2736                     3.0  False
# 2753                     2.0  False
# 1986                     0.0  False

# %%
# by ascending order
df.sort_values(by='Total day charge', ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8             75.0
# 985                       0              346.8             55.0
# 2594                      0              345.3             81.0
# 156                       0              337.4            120.0
# 605                       0              335.5             77.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 365              59.64              216.5             94.0             18.40
# 985              58.96              249.5             79.0             21.21
# 2594             58.70              203.4            106.0             17.29
# 156              57.36              227.4            116.0             19.33
# 605              57.04              212.5            109.0             18.06
#
#       Total night minutes  Total night calls  Total night charge  \
# 365                 253.9              100.0               11.43
# 985                 275.4              102.0               12.39
# 2594                217.5              107.0                9.79
# 156                 153.9              114.0                6.93
# 605                 265.0              132.0               11.93
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 365                 10.1                 9               2.73
# 985                 13.3                 9               3.59
# 2594                11.8                 8               3.19
# 156                 15.8                 7               4.27
# 605                 12.7                 8               3.43
#
#       Customer service calls Churn
# 365                      1.0  True
# 985                      1.0  True
# 2594                     1.0  True
# 156                      0.0  True
# 605                      2.0  True

# %% [markdown]
# Multiple values

# %%
df.sort_values(by=['Total day charge', 'Total day calls'], ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8             75.0
# 985                       0              346.8             55.0
# 2594                      0              345.3             81.0
# 156                       0              337.4            120.0
# 605                       0              335.5             77.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 365              59.64              216.5             94.0             18.40
# 985              58.96              249.5             79.0             21.21
# 2594             58.70              203.4            106.0             17.29
# 156              57.36              227.4            116.0             19.33
# 605              57.04              212.5            109.0             18.06
#
#       Total night minutes  Total night calls  Total night charge  \
# 365                 253.9              100.0               11.43
# 985                 275.4              102.0               12.39
# 2594                217.5              107.0                9.79
# 156                 153.9              114.0                6.93
# 605                 265.0              132.0               11.93
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 365                 10.1                 9               2.73
# 985                 13.3                 9               3.59
# 2594                11.8                 8               3.19
# 156                 15.8                 7               4.27
# 605                 12.7                 8               3.43
#
#       Customer service calls Churn
# 365                      1.0  True
# 985                      1.0  True
# 2594                     1.0  True
# 156                      0.0  True
# 605                      2.0  True

# %% [markdown]
# of course, by index

# %%
df.sort_index().head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
# 2             41.38              121.2            110.0             10.30
# 3             50.90               61.9             88.0              5.26
# 4             28.34              148.3            122.0             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False
# 2                     0.0  False
# 3                     2.0  False
# 4                     3.0  False
