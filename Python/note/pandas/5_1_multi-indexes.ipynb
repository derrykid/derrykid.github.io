# %%
import pandas as pd

df = pd.read_csv('data/telco_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %% [markdown]
# # Multi-indexing
#
# See the following dataframe. It's indexing by 'State' and 'International plan'

# %%
group_df = df.groupby(['State', 'International plan'])['Total day minutes'].describe()
group_df
# Out:
#                           count        mean        std    min      25%  \
# State International plan
# AK    No                   48.0  178.220833  49.723277   58.2  149.600
#       Yes                   4.0  180.350000  56.133917  133.0  135.100
# AL    No                   72.0  185.448611  51.834672   68.7  154.000
#       Yes                   8.0  191.062500  51.075768  127.3  146.325
# AR    No                   47.0  176.768085  51.679843   55.3  146.100
# ...                         ...         ...        ...    ...      ...
# WI    Yes                   8.0  197.187500  74.323664   62.3  155.775
# WV    No                   99.0  171.612121  54.009686   58.0  131.600
#       Yes                   7.0  207.028571  43.211176  146.8  179.500
# WY    No                   67.0  176.225373  53.284088   25.9  141.900
#       Yes                  10.0  206.600000  53.747496   95.9  182.700
#
#                              50%      75%    max
# State International plan
# ...

# %% [markdown]
# its index is different from the dataframe is

# %%
type(group_df.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
# dataframe index
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# It also requires multiple index to access the data:

# %%
group_df.loc['WY', 'No']
# Out:
# count     67.000000
# mean     176.225373
# std       53.284088
# min       25.900000
# 25%      141.900000
# 50%      174.700000
# 75%      216.950000
# max      296.000000
# Name: (WY, No), dtype: float64

# %% [markdown]
# ## Convert the index back to regular indexing

# %%
group_df.reset_index()
# Out:
#     State International plan  count        mean        std    min      25%  \
# 0      AK                 No   48.0  178.220833  49.723277   58.2  149.600
# 1      AK                Yes    4.0  180.350000  56.133917  133.0  135.100
# 2      AL                 No   72.0  185.448611  51.834672   68.7  154.000
# 3      AL                Yes    8.0  191.062500  51.075768  127.3  146.325
# 4      AR                 No   47.0  176.768085  51.679843   55.3  146.100
# ..    ...                ...    ...         ...        ...    ...      ...
# 96     WI                Yes    8.0  197.187500  74.323664   62.3  155.775
# 97     WV                 No   99.0  171.612121  54.009686   58.0  131.600
# 98     WV                Yes    7.0  207.028571  43.211176  146.8  179.500
# 99     WY                 No   67.0  176.225373  53.284088   25.9  141.900
# 100    WY                Yes   10.0  206.600000  53.747496   95.9  182.700
#
#         50%      75%    max
# 0    177.25  210.875  278.4
# ...
